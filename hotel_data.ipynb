# %%
import pandas as pd
from scipy.stats import itemfreq

# %%
hotels = pd.read_csv('hotels.csv')

# %%
us_zipcodes = pd.read_csv('free-zipcode-database.csv')
# Out:
# /Users/work/Programming/freelance/poc/env/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2683: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
us_hotels = hotels[hotels.country_name.str.contains('United States')]

# %%
itemfreq(us_hotels['country_name'])
# Out:
# array([['United States', 125683]], dtype=object)

# %%
us_hotels.to_csv('us_hotels.csv')

# %%
itemfreq(us_hotels['location_id'])
# Out:
# array([[  16344,      94],
#        [  16352,       2],
#        [  16356,       2],
#        ...,
#        [1527127,       1],
#        [1527130,     143],
#        [1527865,      24]])

# %%
us_hotels[us_hotels.location_name.str.contains('Worcester')]
# Out:
#                id                                   name location_name  \
# 113821    1517576  Crowne Plaza Hotel Worcester-Downtown     Worcester
# 373377     394252                Residence Inn Worcester     Worcester
# 493835  964315095     Hampton Inn & Suites-Worcester, MA     Worcester
# 554462     394253            Hilton Garden Inn Worcester     Worcester
# 665738     394249          Holiday Inn Express Worcester     Worcester
# 665739     394251         Quality Inn & Suites Worcester     Worcester
# 794841     394248                        Beechwood Hotel     Worcester
# 794842     394250                    Courtyard Worcester     Worcester
#
#         location_id location_iata   country_name  photos_count
# 113821        19145           ORH  United States            14
# 373377        19145           ORH  United States            50
# 493835        19145           ORH  United States            50
# 554462        19145           ORH  United States            50
# ...

# %%
us_hotels[us_hotels.location_id == 1527130]
# Out:
#                  id                                               name  \
# 44524    1128509395                                    Dune Villas 8-B
# 48288     964436529                     Prominence - Marvelous Getaway
# 70863    1409189787                      Lotus By The Sea Holiday home
# 75019    1554289160                Leeward II #3 in Seagrove Apartment
# 79915    1541484833  Village of South Walton 482-G, Little Gem 30A ...
# 81564    1563407798                                 Patina Respite 113
# 81565    1563407801                                     Patina R&R 189
# 81566    1563407806                                     Kareny Digs 19
# 81567    1563407813                                  Blackwater Home 9
# 96760    1709133074                                   Blue Heaven Home
# 96761    1709133079                       At The Waters Edge Townhouse
# 96762    1709133081                           Absolutely Paradise Home
# ...

# %%
us_zipcodes[us_zipcodes.ZipCodeType == 'STANDARD']
# Out:
#        RecordNumber  Zipcode ZipCodeType                      City State  \
# 0                 1      704    STANDARD               PARC PARQUE    PR
# 1                 2      704    STANDARD       PASEO COSTA DEL SUR    PR
# 2                 3      704    STANDARD             SECT LANAUSSE    PR
# 3                 4      704    STANDARD           URB EUGENE RICE    PR
# 4                 5      704    STANDARD              URB GONZALEZ    PR
# 5                 6      704    STANDARD            URB LA FABRICA    PR
# 6                 7      704    STANDARD         URB MONTE SORIA 2    PR
# 7                 8      704    STANDARD          VILLAS DEL COQUI    PR
# 8                 9      705    STANDARD                  AIBONITO    PR
# 9                10      705    STANDARD              BDA SAN LUIS    PR
# 10               11      705    STANDARD                 BO LLANOS    PR
# 11               12      705    STANDARD        BRISAS DE AIBONITO    PR
# ...

# %%
hotels_list = '''{
  "hotels": [
    {
      "photos": [
        {
          "width": 320,
          "url": "http:\/\/photo.hotellook.com\/image_v2\/limit\/h678963_0\/320\/240.auto",
          "height": 240
        }
      ],
      "checkIn": null,
      "cntSuites": null,
      "distance": 9.7,
      "address": {
        "en": "6th Mile Post gonnoruwa road bandagiriya,"
      },
      "cntRooms": null,
      "photoCount": 6,
      "name": {
        "zh": "\u73ed\u9054\u57fa\u91cc\u9109\u6751\u98ef\u5e97",
        "th": "\u0e1a\u0e31\u0e19\u0e14\u0e32\u0e01\u0e34\u0e23\u0e35 \u0e27\u0e34\u0e25\u0e40\u0e25\u0e08",
        "en": "Bandagiri Village"
      },
      "cityId": 895,
      "checkOut": null,
      "cntFloors": null,
      "rating": 0,
      "yearRenovated": null,
      "stars": 0,
      "yearOpened": null,
      "propertyType": 0,
      "facilities": [
        131,
        56,
        50,
        14,
        40,
        13,
        11
      ],
      "link": "\/lk\/weerawila-895\/bandagiri_village-678963.html",
      "popularity": 600,
      "location": {
        "lat": 6.23485,
        "lon": 81.14245
      },
      "shortFacilities": [
        "air conditioning",
        "parking",
        "laundry",
        "wi-fi in public areas",
        "fitness"
      ],
      "pricefrom": 70,
      "photosByRoomType": {
        "1": 10,
        "25": 10
      },
      "id": 678963,
      "poi_distance": {
        "70643": 94961,
        "70649": 94654,
        "70650": 52747,
        "71334": 10762
      }
    }
  ],
  "gen_timestamp": 1480288607.1638,
  "pois": [
    {
      "confirmed": true,
      "rating": 0,
      "location": {
        "lat": 5.990833,
        "lon": 80.733333
      },
      "name": "Dickwella Airport",
      "geom": {
        "type": "Point",
        "coordinates": [
          80.733333,
          5.990833
        ]
      },
      "category": "airport",
      "id": 70650
    }
  ]
}'''
